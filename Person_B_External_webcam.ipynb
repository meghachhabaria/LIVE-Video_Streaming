# %%
from VideoStream import VideoStream

# %%
#Change IPs and Port according to you

# %%
VideoStream(socket_name=("",234),stream_mode="initiater",title="Person B",cam_index=1,peering_name=("192.168.52.2",1234)).startVideo()
